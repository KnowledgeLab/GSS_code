# %%
#######################
# this is an improvement over the code: GSSproject/Code/DEPRECATED--get-random-articles-from-articleClasses-pickle.py

# can use this code to give data to Julianna St Onge (UChicago RA). for example, per email from James Evans 2016-05-22

# %%
import cPickle as cp
from random import sample
import sys
import pandas as pd
import pickle

sys.path.append('../')    
import GSSUtility as GU
sys.path.append('../Code/')
from articleClass import *

# %%
pathToData = '../Data/'
articleClasses = cp.load(open(pathToData + 'articleClasses.pickle', 'rb'))

# %%
def filterArticles(articleClasses, GSSYearsUsed=True, GSSYearsPossible=False, unusedGSSYears=False, noIVs=True, noDVs=True, \
                    centralIVs=True, nextYearBound=0, yearPublished=False, linearModels=True, GSSCentralVariable=False):
    '''
    This function filters the articleClasses list according to the following criteria.
    arguments:
     - noIVs: skip if no IVs specified
     - noDVs: skip if no DVs specified
     - GSSYearsPossible: skip if there are no GSS years possible besides the ones the article used
     - unusedGSSYears=False: If True, then keep only those articles which have some GSS Years they could have used, but didn't
     - centralIV: skip if there is no IV(s) designated as "central"
     - nextYearBound = int: skip if next future year of data is not within "int" of last year used
                     = 0 by default, in which case it's not used
     - yearPublished=False: if set to True, yearPublished is required to be not None
     - GSSCentralVariable=False: if True, keep only those articles where GSSCentralVariable is True in the mysql
                                 table gss_question
     - linearModels=False: if True, keep only those articles where model type is .. and I should think about what to use here.
     - TODO: ADD AN "UNUSED YEARS" filter

    '''
    indicesToKeep = []
    
    pathToData = '../Data/'
    if GSSCentralVariable:
        gssCentral = cp.load(open(pathToData + 'ARTICLEID_GSS_CENTRAL_VARIABLE.pickle', 'rb'))

    if linearModels:
        modelUsed = pd.read_pickle(pathToData + 'ARTICLEID_AND_TRUE_IF_LINEAR_NONLINEAR.pickle')

    for ind, a in enumerate(articleClasses):  # a = article
        
        # skip article if there is no info on DVs or IVs
        # Should we change this to skip only if BOTH controls AND IVs are not there?
        if noDVs:
            if len(a.DVs) < 1: continue
        
        if noIVs: 
            if len(a.IVs) < 1: continue

        if GSSYearsUsed:         
            # if there is no used years of GSS possible to run the data on, then just skip this article
            if len(a.GSSYearsUsed) < 1: continue
            
        if GSSYearsPossible:         
            # if there is no un-used years of GSS possible to run the data on, then just skip this article
            if len(a.GSSYearsPossible) < 1: continue

        if unusedGSSYears:
            unusedEarlyYears = [yr for yr in a.GSSYearsPossible if yr <= max(a.GSSYearsUsed)]
            if len(unusedEarlyYears)==0: continue
            
        if centralIVs:    
            # if GSS is not the central dataset used then skip
            if len(a.centralIVs) < 1: continue
                   
        if nextYearBound:
            # nextYear is an integer that specifies how soon the next available year of data is supposed to be.
            # e.g. if nextYearBound = 4, then the new future year of data is to occur within 4 years of the last year of data
            # actually used. 
            maxYearUsed = max(a.GSSYearsUsed)
            futureYearsPossible = [yr for yr in a.GSSYearsPossible if yr > maxYearUsed]
            if not futureYearsPossible or min(futureYearsPossible) > maxYearUsed + nextYearBound: continue
                   
        if yearPublished:
            if not a.yearPublished: continue
                        
        if GSSCentralVariable:
            if a.articleID not in gssCentral or gssCentral[a.articleID]==False: continue
        
        if linearModels:
            if a.articleID not in modelUsed: continue            
            
        # if the article survived all of the checks above, add it to the list
        indicesToKeep.append(ind)
    
    return [articleClasses[ind] for ind in indicesToKeep] # return elements that have survived
                                                            # the filtering

# %%
# note, nextYearBound = 40 essentially requires that there's at least one future year
articlesToUse = filterArticles(articleClasses, GSSYearsUsed=True, GSSYearsPossible=True, \
                                    centralIVs=True, nextYearBound=40, linearModels=False)        

suitable_articles = []
for article in articlesToUse:
    maxYearUsed = max(article.GSSYearsUsed)
    futureYearsPossible = [yr for yr in article.GSSYearsPossible if yr > maxYearUsed]
    suitable_articles.append( (article.articleID, futureYearsPossible) )  
    
sample_i = sample(suitable_articles, 50)

# %%
', '.join([str(el[0]) for el in sample_i])
# Out:
# '3676, 3017, 7739, 6333, 4173, 6796, 932, 6926, 2253, 2586, 7638, 7291, 2554, 4400, 4374, 2364, 2506, 6553, 7790, 2789, 2163, 4618, 1605, 1037, 6664, 1310, 2565, 2892, 1565, 6720, 6188, 6521, 6877, 1709, 1793, 348, 59, 6908, 1510, 1341, 2146, 2466, 3452, 2822, 1533, 3231, 2465, 716, 2171, 2037'

# %%
# code below is used to give data to Julianna, where it's clear which articles use regression models and which don't
# per email with James Evans 2016-05-22. but note that i'm using model==linear_nonlinear, and it's not clear that this is 
# the model type that designates regressions...

# %%
all_articles = [a.articleID for a in filterArticles(articleClasses, 
                                  GSSYearsUsed=True, 
                                  GSSYearsPossible=False, 
                                  centralIVs=False, 
                                  nextYearBound=0, 
                                  linearModels=False)]

linear_articles = [a.articleID for a in filterArticles(articleClasses, 
                                  GSSYearsUsed=True, 
                                  GSSYearsPossible=False, 
                                  centralIVs=False, 
                                  nextYearBound=0, 
                                  linearModels=True)]

# %%
data = []
for a in all_articles:
    data.append([a, True if a in linear_articles else False])

all_articles = pd.DataFrame(data, columns=['true_article_id', 'uses_linear_models'])

# %%
titles = pd.read_csv('../Data/true_article_id_name_year_title_ALL.csv', index_col=0)
titles.index = titles.true_article_id
titles.head()
# Out:
#                  true_article_id author_1_last_name  year_published  \
# true_article_id
# 1                              1            Alesina            2000
# 2                              2            Alesina            2001
# 3                              3          Alexander            2001
# 4                              4              Algan            2005
# 5                              5                Ali            2001
#
#                                                              title
# true_article_id
# 1                       Participation in Heterogeneous Communities
# 2                                      Why Europeans Fear the Rich
# 3                "Emotional Health, Well-Being, and Religion as...
# 4                Civic Attitudes and the Design of Labor Market...
# 5                                       Survey of Pastoral Leaders

# %%
all_articles_and_titles = pd.merge(left=all_articles, right=titles, on='true_article_id')

# %%
file_articles_from_next = open('minianalysis_next_year/minianalysis_next_year_list_of_articles_used.csv', 'rb').read()
articles_from_next = map(int, file_articles_from_next.split(','))

file_articles_from_cognate = open('minianalysis_cognate_variables/minianalysis_cognate_variables_list_of_articles_used.csv', 'rb').read()
articles_from_cognate = map(int, file_articles_from_cognate.split(','))

file_articles_from_x_years = open('minianalysis_last_year_used_vs_x_years_into_future/minianalysis_x_years_list_of_articles_used.csv', 'rb').read()
articles_from_x_years = map(int, file_articles_from_x_years.split(','))

# %%
all_articles_and_titles['used_in_last_vs_next'] = False
all_articles_and_titles.loc[all_articles_and_titles.true_article_id.isin(articles_from_next), 'used_in_last_vs_next'] = True

all_articles_and_titles['used_in_cognate'] = False
all_articles_and_titles.loc[all_articles_and_titles.true_article_id.isin(articles_from_cognate), 'used_in_cognate'] = True

all_articles_and_titles['used_in_x_years_into_future'] = False
all_articles_and_titles.loc[all_articles_and_titles.true_article_id.isin(articles_from_x_years), 'used_in_x_years_into_future'] = True

# %%
all_articles_and_titles
# Out:
#      true_article_id uses_linear_models author_1_last_name  year_published  \
# 0               2952              False            Grigsby            1992
# 1               4013               True             Kelley            1998
# 2               4055               True            Khullar            1988
# 3               2558               True              Glenn            1989
# 4               4434               True               Leon            1982
# 5               3690              False      Jackson-Beeck            1980
# 6               4266               True          Kyvelidis            2001
# 7               5651              False               Paik            1995
# 8               6188              False               Roof            1979
# 9               6439               True       Schmalzbauer            1993
# 10              4007               True             Kelley            1993
# 11              1043               True             Butler            1991
# 12              1845              False               Duke            1991
# 13              3347              False          Hirschman            1983
# 14              3573              False             Hunter            1984
# 15              4133               True            Kluegel            1987
# 16              5096               True             Miller            1996
# 17              1211               True             Chaves            1990
# 18              1242              False            Cherlin            1981
# 19              2291               True             Folbre            1995
# 20                30               True               Abad            1994
# 21              6840               True              Smith            1981
# 22               224               True              Alwin            1999
# 23                55              False              Acock            1989
# 24               196               True              Alwin            1991
# 25               492               True               Beck            1978
# 26               638               True              Blake            1986
# 27               660               True               Blau            1991
# 28              1313              False           Clemente            1977
# 29              1324              False              Clogg            1982
# ..               ...                ...                ...             ...
# 739             1679              False      de Figueiredo            2003
# 740             1689              False           DeFronzo            1993
# 741             1793              False                NaN            1988
# 742             1802              False             Doring            1994
# 743             1938              False           Eismeier            1982
# 744             2003              False             Gibson            1995
# 745             2051              False             Entman            1980
# 746             2207              False             Ferree            1974
# 747             2548               True             Glaser            1997
# 748             2612              False              Glenn            1982
# 749             2617              False              Glenn            1982
# 750             2692              False           Mitchell            1978
# 751             2813              False            Greeley            1977
# 752             2922               True              Green            1989
# 753             2965              False             Grover            1995
# 754             3053              False               Hall            1986
# 755             3095               True            Hammond            1986
# 756             3210               True              Hayes            1993
# 757             3607              False             Hynson            1976
# 758             3959              False              Keene            1984
# 759             4154              False              Knoke            1979
# 760             4291              False               Ladd            1985
# 761             4297               True               Ladd            1989
# 762             4302              False               Ladd            1976
# 763             4310              False               Ladd            1985
# 764             4456              False             Levine            1993
# 765             4665              False               Lynn            2004
# 766             4887              False           Matthews            1992
# 767             4954              False         McCutcheon            1985
# 768             6723              False           Sigelman            1990
#
#                                                  title used_in_last_vs_next  \
# 0                                  Women Change Places                 True
# 1              Sources of National Pride in 24 Nations                False
# 2    Race and Gender Variation in Social Participat...                False
# 3    "Duration of Marriage, Family Composition, and...                 True
# 4    White Prejudice Towards Blacks: A Hypothesis T...                False
# 5                    The Social World of Heavy Viewers                 True
# 6    Measuring Post-Materialism in Post-Socialist S...                False
# 7    Predicting Television Extreme Viewers and Nonv...                False
# 8    Socioeconomic Differentials Among White Socio-...                 True
# 9    Evangelicals in the New Class: Class Versus Su...                 True
# 10   The Legitimation of Inequality: Occupational E...                False
# 11   Ethnicity and Entrepreneurship in America: Tow...                False
# 12                      Labels Mask 'Latino' Diversity                False
# 13                  America's Melting Pot Reconsidered                 True
# 14   Religion and Political Civility: The Coming Ge...                 True
# 15   "Macro-Economic Problems, Belief about the Poo...                 True
# 16   On the Stability of Church Attendance Patterns...                 True
# 17   Reply: Holding the Cohort: Reply to Hout and G...                 True
# 18   Trends in U.S. Men's and Women's Sex Role Atti...                False
# 19          Sexual Orientation Showing Up in Paychecks                False
# 20   Filipino Religiosity: Some International Compa...                False
# 21      "Tolerance of School Desegregation, 1954-1977"                 True
# 22   Aging Versus Cohort Interpretations of Interco...                False
# 23   Is It Family Structure or Socioeconomic Status...                False
# 24   Family of Origin and Cohort Differences in Ver...                False
# 25   Stratification in a Dual Economy: A Sectoral M...                 True
# 26   Sibship Size and Educational Stratification: R...                 True
# 27          Interpersonal Choice and Networks in China                False
# 28   Fear of Crime in the United States: A Multivar...                 True
# 29   Using Association Models in Sociological Resea...                 True
# ..                                                 ...                  ...
# 739  Are Patriots Bigots? An Inquiry into the Vices...                False
# 740  Being Female and Less Deviant: The Direct and ...                False
# 741                                      Divorce Loses                 True
# 742  Public Perceptions of the Proper Role of the S...                False
# 743  "Public Preferences About Government Spending:...                False
# 744  "The Political Freedom of African Americans: A...                 True
# 745                    Media and the Conservative Myth                False
# 746  A Woman for President? Changing Response: 1958...                 True
# 747  Interregional Migration and Political Resocial...                 True
# 748  "Enjoyment of Work by Full-time Workers in the...                 True
# 749      Regional Differences in Attitudes Toward Work                False
# 750                                 The Public's Views                 True
# 751           How Conservative Are American Catholics?                False
# 752  The Missing Link: Political Activists and Supp...                False
# 753  Who Appreciates Family Responsive Human Resour...                False
# 754             Race Differences in Abortion Attitudes                False
# 755                                            Yuppies                False
# 756  "Political Efficacy:  A Comparative Study of t...                False
# 757      Teachers' Preferences of Children's Qualities                False
# 758                     Who's the Fairest of Them All?                 True
# 759  Stratification and the Dimensions of American ...                False
# 760     As the Realignment Turns: A Drama in Many Acts                False
# 761    A Debate on Abortion: The Partisan Consequences                 True
# 762  Liberalism Upside Down: The Inversion of the N...                 True
# 763  "On Mandates, Realignments, and the 1984 Presi...                False
# 764  The Effect of Non-Traditional Attitudes on Mar...                False
# 765  New Evidence of Dysgenic Fertility for Intelli...                False
# 766              Financial Satisfaction Among Teachers                False
# 767  A Latent Class Analysis of Tolerance for Nonco...                 True
# 768  "Answering the 1,000,000-Person Question: The ...                 True
#
#     used_in_cognate used_in_x_years_into_future
# 0             False                        True
# 1             False                        True
# 2             False                        True
# 3             False                        True
# 4              True                        True
# 5              True                        True
# 6             False                       False
# 7             False                        True
# 8              True                        True
# 9              True                        True
# 10            False                       False
# 11            False                        True
# 12            False                       False
# 13            False                        True
# 14            False                        True
# 15            False                        True
# 16            False                        True
# 17            False                        True
# 18            False                        True
# 19            False                       False
# 20            False                       False
# 21             True                        True
# 22             True                       False
# 23            False                        True
# 24             True                       False
# 25             True                        True
# 26            False                        True
# 27             True                       False
# 28            False                        True
# 29            False                        True
# ..              ...                         ...
# 739           False                       False
# 740           False                       False
# 741           False                        True
# 742           False                        True
# 743            True                       False
# 744           False                        True
# 745           False                       False
# 746            True                        True
# 747           False                        True
# 748           False                        True
# 749           False                       False
# 750           False                        True
# 751           False                       False
# 752           False                       False
# 753           False                       False
# 754           False                       False
# 755            True                       False
# 756            True                       False
# 757           False                       False
# 758           False                        True
# 759            True                       False
# 760           False                       False
# 761            True                        True
# 762            True                        True
# 763           False                       False
# 764            True                       False
# 765           False                        True
# 766           False                       False
# 767            True                        True
# 768           False                        True
#
# [769 rows x 8 columns]

# %%
all_articles_and_titles.to_csv('../Data/all_articles_linear_models_and_titles.csv', index=False)
